# %%
# Cell 1 - Calculate your age in weeks
age_years = 0
age_weeks = age_years * 52
print(f"I am {age_years} years old", end=", ")
print(f"which is {age_weeks:,} weeks.")

# %%
# Cell 2 - Calculate your age in seconds

# %%
# Cell 3

# %%
# Cell 4

# %%
# Cell 5

# %%
# Cell 6

# %%
# Cell 7

# %%
# Cell 8

# %%
# Cell 9

# %%
# Cell 10

# %%
# Cell 11

# %%
# Cell 12
